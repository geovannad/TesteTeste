# %%
import pandas as pd
 
df = pd.DataFrame({'Nome':['Nisfla', 'Santi', 'Modolo', 'Grilo','Daniel', 'Myrna'],
              'Aulas': [6,2,2,2,5,0],
              'Nivel_Educacional':['Mestre', 'Mestre', 'Mestre','Doutorando',
              'Mestre', 'Mestre'], 'Tempo_Refeicao':[10.5
              ,15.7,12.6, 11.7, 20.5, 15]})

# %%
display(df)
# Out:
#      Nome  Aulas Nivel_Educacional  Tempo_Refeicao
# 0  Nisfla      6            Mestre            10.5
# 1   Santi      2            Mestre            15.7
# 2  Modolo      2            Mestre            12.6
# 3   Grilo      2        Doutorando            11.7
# 4  Daniel      5            Mestre            20.5
# 5   Myrna      0            Mestre            15.0

# %%
import pandas as pd
df2 = pd.read_csv('dataset_rh.csv', sep = ';')
display(df2)
# Out:
#     Funcionário  Anos de Serviço  Salário Anual (R$)  \
# 0             1               13              92.489
# 1             2               16              81.504
# 2             3                1              89.866
# 3             4                4              51.723
# 4             5                4              83.890
# 5             6                8              57.591
# 6             7               10              98.146
# 7             8               19              99.300
# 8             9                5             111.557
# 9            10                7              60.006
# 10           11               13              43.560
# 11           12                2             101.713
# 12           13                7              85.444
# 13           14                8              86.522
# 14           15               15              60.737
# 15           16               18              68.647
# 16           17                6             101.353
# 17           18               14              52.134
# 18           19                9             100.535
# 19           20               10              87.883
# 20           21               17             103.360
# 21           22                6              91.811
# 22           23               16              49.781
# 23           24               16              59.340
# 24           25                1              67.257
# 25           26               19              56.298
# 26           27                4              52.372
# 27           28               18              44.420
# 28           29               15             102.079
# 29           30                8             119.860
#
#     Horas de Treinamento por Ano  Avaliação de Desempenho
# 0                              8                        4
# 1                             17                        5
# 2                             19                        2
# 3                             20                        3
# 4                             25                        4
# 5                             28                        2
# 6                             20                        3
# 7                             18                        2
# 8                             26                        5
# 9                             10                        3
# 10                             5                        4
# 11                            36                        1
# 12                            10                        4
# 13                            35                        3
# 14                             5                        4
# 15                            39                        1
# 16                            34                        1
# 17                             8                        1
# 18                            39                        4
# 19                            18                        3
# 20                            26                        4
# 21                            14                        1
# 22                             5                        5
# 23                            15                        1
# 24                            28                        1
# 25                             7                        3
# 26                            39                        4
# 27                            35                        3
# 28                             8                        4
# 29                            23                        1
